# %%
from binance import Client
from time import time
from trade import MyCLient, create_client, rebalance, get_symbols_info
import os
import dotenv
from pprint import pprint

# %%
API_KEY = "GRJaQlXdXyjHzKJv6uyfxIO1z7mTqq4QFzF0yFt4REJS1krN9lN2QipoDjfAg9lE"
SECRET_KEY = "J6rVvqYmHcSnQ6feekOxetR7WnCVGbDSt7qwzjJoUyMuBE6gpmb6Gb6Q6E9gfj7v"

t0 = time()
for i in range(100):
    client = Client(API_KEY, SECRET_KEY, testnet=True)
t1 = time()

print(f"Time to create client: {t1-t0} seconds")

# %%
(0.021111 // 0.01) * 0.01
# Out:
# 0.02

# %%
# client = create_client(API_KEY, SECRET_KEY, testnet=True)
client = create_client("mCibYjeQcYHk1JKlZZu75klg6PTnI2TEg0KBec9CLDDmQ8x87BKU6p386abH7NbN",
                       "mJQymxwhlLHYJ4rgfyEp2ejR3vWBVYbkbgPuIuv18KFv4lANJZ3TqLzNOq0fmsvf")
for symbol, info in get_symbols_info(client).items():
    print(symbol, info["filters"][1]["minQty"]==info["filters"][1]["stepSize"])
# Out:
# ETHBTC True
# LTCBTC True
# BNBBTC True
# NEOBTC True
# QTUMETH True
# EOSETH True
# SNTETH True
# BNTETH True
# BCCBTC True
# GASBTC True
# BNBETH True
# BTCUSDT True
# ETHUSDT True
# HSRBTC True
# OAXETH True
# DNTETH True
# MCOETH True
# ICNETH True
# MCOBTC True
# WTCBTC True
# WTCETH True
# LRCBTC True
# LRCETH True
# QTUMBTC True
# YOYOBTC True
# OMGBTC True
# OMGETH True
# ZRXBTC True
# ZRXETH True
# STRATBTC True
# STRATETH True
# SNGLSBTC True
# SNGLSETH True
# BQXBTC True
# BQXETH True
# KNCBTC True
# KNCETH True
# FUNBTC True
# FUNETH True
# SNMBTC True
# SNMETH True
# NEOETH True
# IOTABTC True
# IOTAETH True
# LINKBTC True
# LINKETH True
# XVGBTC True
# XVGETH True
# SALTBTC True
# SALTETH True
# MDABTC True
# MDAETH True
# MTLBTC True
# MTLETH True
# SUBBTC True
# SUBETH True
# EOSBTC True
# SNTBTC True
# ETCETH True
# ETCBTC True
# MTHBTC True
# MTHETH True
# ENGBTC True
# ENGETH True
# DNTBTC True
# ZECBTC True
# ZECETH True
# BNTBTC True
# ASTBTC True
# ASTETH True
# ...
